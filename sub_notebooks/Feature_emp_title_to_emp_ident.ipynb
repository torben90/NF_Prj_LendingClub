# %%
import pandas as pd
import re

# %%
df = pd.read_pickle('../data/clean_pass_01p1.pkl')

# %%
(re.search('Army','ARMY',re.I) is None) == False
# Out:
# True

# %%
# get Army
df.emp_title.value_counts()
df['emp_Army'] = df.emp_title.apply(lambda x: (re.search('Army|Military',x ,re.I) is None) == False)

# %%
df[~df.emp_Army].emp_title
# Out:
# 1                                          Ryder
# 3                            AIR RESOURCES BOARD
# 5                           Veolia Transportaton
# 6                      Southern Star Photography
# 7                                MKC Accounting
# 9                                      Starbucks
# 10                         Southwest Rural metro
# 11                                          UCLA
# 12           Va. Dept of Conservation/Recreation
# 13                                        Target
# 14                                         SFMTA
# 15                      Internal revenue Service
# 16                             Chin's Restaurant
# 17                                      Duracell
# 18                         Connection Inspection
# 19                  Network Interpreting Service
# 20              Archdiocese of Galveston Houston
# 21                                Osram Sylvania
# 22                                     Value Air
# 23                              Wells Fargo Bank
# 24                               bmg-educational
# 25                Winfield Pathology Consultants
# 26                                   nyc transit
# 27                                     Frito Lay
# 28       Shands Hospital at the University of Fl
# 29                                Oakridge homes
# 31            Audubon Mutual Housing Corporation
# 33                        Good Samaritan Society
# 34                          GREG BARRETT DRYWALL
# 35                               Sharp Lawn Inc.
#                           ...
# 42420                         Miami Dade College
# 42421                      enterprise rent a car
# 42422                      College of the Ozarks
# 42423                        Lead Media Partners
# 42424          International finance Corporation
# 42425                                Wilson Tire
# 42426                        Mustang Enterprises
# 42427                                       SELF
# 42428                            Rouge Moira LLC
# 42429                               Williams Lea
# 42430                                  Homedepot
# 42431                   Dr. Cathy Andricsak, DDS
# 42432                          Peter J Oliff DDS
# 42434                             PGIII Services
# 42435                                    retired
# 42436                          Purdue University
# 42437                  Winkel Construction, Inc.
# 42438                          disabled, student
# 42439                                        IBM
# 42440             Georgia Institue of Technology
# 42441                       swift transportation
# 42442                          Thomson Financial
# 42443                        national employment
# 42444                                      Sears
# 42446                       neurology associates
# 42448                    Brookdale Senior Living
# 42449                Crawford Tracey Corporation
# 42454                          PEER Center, Inc.
# 42466                Securitas Security Services
# 42474                           LendingTree, LLC
# Name: emp_title, Length: 38387, dtype: object

# %%
df[df.emp_Army].shape
# Out:
# (476, 47)

# %%
# get self
df['emp_Self'] = df.emp_title.apply(lambda x: (re.search('self',x ,re.I) is None) == False)

# %%
df[~df.emp_Self & ~df.emp_Army].emp_title
# Out:
# 1                                          Ryder
# 3                            AIR RESOURCES BOARD
# 5                           Veolia Transportaton
# 6                      Southern Star Photography
# 7                                MKC Accounting
# 9                                      Starbucks
# 10                         Southwest Rural metro
# 11                                          UCLA
# 12           Va. Dept of Conservation/Recreation
# 13                                        Target
# 14                                         SFMTA
# 15                      Internal revenue Service
# 16                             Chin's Restaurant
# 17                                      Duracell
# 18                         Connection Inspection
# 19                  Network Interpreting Service
# 20              Archdiocese of Galveston Houston
# 21                                Osram Sylvania
# 22                                     Value Air
# 23                              Wells Fargo Bank
# 24                               bmg-educational
# 25                Winfield Pathology Consultants
# 26                                   nyc transit
# 27                                     Frito Lay
# 28       Shands Hospital at the University of Fl
# 29                                Oakridge homes
# 31            Audubon Mutual Housing Corporation
# 33                        Good Samaritan Society
# 34                          GREG BARRETT DRYWALL
# 35                               Sharp Lawn Inc.
#                           ...
# 42419                                   local 16
# 42420                         Miami Dade College
# 42421                      enterprise rent a car
# 42422                      College of the Ozarks
# 42423                        Lead Media Partners
# 42424          International finance Corporation
# 42425                                Wilson Tire
# 42426                        Mustang Enterprises
# 42428                            Rouge Moira LLC
# 42429                               Williams Lea
# 42430                                  Homedepot
# 42431                   Dr. Cathy Andricsak, DDS
# 42432                          Peter J Oliff DDS
# 42434                             PGIII Services
# 42435                                    retired
# 42436                          Purdue University
# 42437                  Winkel Construction, Inc.
# 42438                          disabled, student
# 42439                                        IBM
# 42440             Georgia Institue of Technology
# 42441                       swift transportation
# 42442                          Thomson Financial
# 42443                        national employment
# 42444                                      Sears
# 42446                       neurology associates
# 42448                    Brookdale Senior Living
# 42449                Crawford Tracey Corporation
# 42454                          PEER Center, Inc.
# 42466                Securitas Security Services
# 42474                           LendingTree, LLC
# Name: emp_title, Length: 38156, dtype: object

# %%
df[df.emp_Self].shape
# Out:
# (231, 45)

# %%
df_company = pd.read_csv('../data/forbes2013.csv')
df_company.shape
# Out:
# (1984, 7)

# %%
df_company.head()
# Out:
#    Rank                   Company  Sales($billion)  Profits($billion)  Assets  \
# 0    40         Commonwealth Bank             47.8                7.3   735.2
# 1    44              BHP Billiton             72.2               15.4   129.3
# 2    48     Westpac Banking Group             43.9                6.2   699.6
# 3    58  National Australian Bank             49.2                4.2   791.3
# 4    66                       ANZ             37.5                5.9   666.9
#
#    Market Value    Country
# 0         117.5  Australia
# 1         184.7  Australia
# 2          98.9  Australia
# 3          76.3  Australia
# 4          81.2  Australia

# %%
df['emp_KnownCompany'] = df.emp_title.isin(df_company.Company)

# %%
df[df.emp_KnownCompany].shape
# Out:
# (1988, 45)

# %%
df.shape
# Out:
# (38818, 45)

# %%
 df.target.value_counts()
# Out:
# 1.0    32976
# 0.0     5842
# Name: target, dtype: int64

# %%
df[df.emp_Self | df.emp_Army | df.emp_KnownCompany]
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv term  int_rate  installment  \
# 9         5375.0       5375.0      5350.000000  60m    0.1269       121.45
# 13        3000.0       3000.0      3000.000000  36m    0.0991        96.68
# 76       11000.0      11000.0     11000.000000  36m    0.1349       373.24
# 81       10000.0      10000.0     10000.000000  36m    0.1427       343.09
# 130       7000.0       7000.0      7000.000000  36m    0.1269       234.82
# 149       8450.0       8450.0      8425.000000  60m    0.1677       208.97
# 160      16000.0      16000.0      8150.000000  60m    0.1527       382.92
# 180      14000.0      14000.0     14000.000000  36m    0.1065       456.03
# 225      26000.0      26000.0     25975.000000  60m    0.1677       642.96
# 250       4000.0       4000.0      4000.000000  36m    0.1903       146.69
# 277      18000.0      18000.0     17950.000000  36m    0.0890       571.56
# 303      14000.0      14000.0     14000.000000  36m    0.1427       480.33
# 317      20000.0      20000.0     19975.000000  60m    0.1527       478.64
# 331      15000.0      15000.0     15000.000000  36m    0.1242       501.23
# 347      16000.0      11625.0     11368.734456  60m    0.1903       301.76
# 352      21500.0      16975.0     15953.426394  60m    0.1758       427.19
# 414      20000.0      16925.0     11925.000000  60m    0.1465       399.55
# 180       B        B2                      MetLife         3.0  ...
# 225       D        D2                      PepsiCo        10.0  ...
# 250       E        E2                          IBM        10.0  ...
# 277       A        A5                    Accenture         5.0  ...
# 303       C        C2                     Raytheon         6.0  ...
# 317       C        C4       Level 3 Communications        10.0  ...
# 331       B        B4           Jacobs Engineering         6.0  ...
# 347       E        E2                      US Army         8.0  ...
# 352       D        D4   US Army Corps of Engineers         2.0  ...
# 414       C        C3                       Macy's        10.0  ...
# 420       A        A2                     Qualcomm         3.0  ...
# 465       B        B5                     Ericsson        10.0  ...
# 482       A        A3              Bank of America        10.0  ...
# 504       B        B4              Bank of America         2.0  ...
# 538       B        B3                          IBM         7.0  ...
# 567       B        B1                      Comcast         1.0  ...
# 576       B        B1                self employed        10.0  ...
# 584       B        B1               JPMorgan Chase         0.5  ...
# 590       C        C1                       Target         0.5  ...
# 596       B        B4             Juniper Networks         7.0  ...
# 641       A        A2                    JC Penney         3.0  ...
# 672       E        E2                    U.S. Army        10.0  ...
# 711       A        A5               General Motors         9.0  ...
# ...     ...       ...                          ...         ...  ...
# 42029     G        G4                         Self        10.0  ...
# 42035     B        B5                       Kroger         6.0  ...
# 42036     D        D2                    Nordstrom         4.0  ...
# 42054     G        G4               Morgan Stanley         1.0  ...
# 42060     C        C3                 Selfemployed         7.0  ...
# 42075     C        C1                         Self         5.0  ...
# 42080     G        G5                         SELF         5.0  ...
# 42084     E        E2                      Comcast         1.0  ...
# 42104     F        F1                  BAE Systems         2.0  ...
# 42115     B        B2             Costco Wholesale         1.0  ...
# 42119     F        F4                         Army        10.0  ...
# 42127     D        D4                       Kohl's         0.5  ...
# 42137     D        D3                       Adecco         0.5  ...
# 42148     D        D5                self employed         5.0  ...
# 42153     E        E5        Magnolia Self Storage         1.0  ...
# 42175     B        B5              Bank of America         0.5  ...
# 42184     C        C4    Self-Employed, Contractor         1.0  ...
# 42207     C        C1          Goldman Sachs Group         0.5  ...
# 42221     F        F2                      US Army         3.0  ...
# 42276     E        E2                     Best Buy         1.0  ...
# 42367     F        F2                Self Employed         1.0  ...
# 42374     E        E2  United States Army Reserves         2.0  ...
# 42377     G        G4                Self Employed         1.0  ...
# 42382     G        G1                     Best Buy         3.0  ...
# 42387     C        C4                Self Employed         1.0  ...
# 42390     D        D5                   Home Depot         1.0  ...
# 42403     B        B1              Wal-Mart Stores         1.0  ...
# 42418     A        A5                      us army         2.0  ...
# 42427     C        C3                         SELF         9.0  ...
# 42439     F        F1                          IBM         1.0  ...
#
#       collection_recovery_fee  last_pymnt_amnt last_credit_pull_d  \
# 9                      2.5200           121.45           Mar-2013
# 13                     0.0000           102.43           Jun-2016
# 76                     0.0000          1491.29           Oct-2014
# 81                     0.0000          8962.31           Feb-2013
# 130                    0.0000           238.06           Jan-2015
# 149                    0.0000          3239.35           Sep-2015
# 160                    0.0000           199.56           Nov-2015
# 180                    0.0000         10643.16           Dec-2012
# 225                   12.2700           642.96           Jun-2013
# 250                    0.0000           785.51           May-2016
# 277                    0.0000         10185.73           Jun-2013
# 303                    0.0000           509.76           Dec-2014
# 317                    9.8900           478.64           Mar-2013
# ...                    ...            ...    ...        ...      ...
# 42029                    0              1    0.0      False    False
# 42035                    0              1    1.0       True    False
# 42036                    0              1    0.0      False    False
# 42054                    0              1    1.0       True    False
# 42060                    0              1    0.0      False    False
# 42075                    0              1    0.0      False    False
# 42080                    0              1    1.0       True    False
# 42084                    0              1    1.0       True    False
# 42104                    0              1    1.0       True    False
# 42115                    0              1    0.0      False    False
# 42119                    0              1    1.0       True     True
# 42127                    0              1    1.0       True    False
# 42137                    0              1    1.0       True    False
# 42148                    0              1    0.0      False    False
# 42153                    1              1    1.0       True    False
# 42175                    0              1    0.0      False    False
# 42184                    0              1    1.0       True    False
# 42207                    0              1    1.0       True    False
# 42221                    0              1    0.0      False     True
# 42276                    0              1    1.0       True    False
# 42367                    0              1    0.0      False    False
# 42374                    0              1    1.0       True     True
# 42377                    0              1    0.0      False    False
# 42382                    0              1    1.0       True    False
# 42387                    0              1    1.0       True    False
# 42390                    0              1    1.0       True    False
# 42403                    0              1    0.0      False    False
# 42418                    0              1    1.0       True     True
# 42427                    0              1    0.0      False    False
# 42439                    0              1    1.0       True    False
#
#        emp_Self  emp_KnownCompany
# 9         False              True
# 13        False              True
# 76        False             False
# 81        False              True
# 130       False              True
# 149       False              True
# 160       False             False
# 180       False              True
# 225       False              True
# 250       False              True
# 277       False              True
# 303       False              True
# 317       False              True
# 331       False              True
# 347       False             False
# 352       False             False
# 414       False              True
# 420       False              True
# 465       False              True
# 482       False              True
# 504       False              True
# 538       False              True
# 567       False              True
# 576        True             False
# 584       False              True
# 590       False              True
# 596       False              True
# 641       False              True
# 672       False             False
# 711       False              True
# ...         ...               ...
# 42029      True             False
# 42035     False              True
# 42036     False              True
# 42054     False              True
# 42060      True             False
# 42075      True             False
# 42080      True             False
# 42084     False              True
# 42104     False              True
# 42115     False              True
# 42119     False             False
# 42127     False              True
# 42137     False              True
# 42148      True             False
# 42153      True             False
# 42175     False              True
# 42184      True             False
# 42207     False              True
# 42221     False             False
# 42276     False              True
# 42367      True             False
# 42374     False             False
# 42377      True             False
# 42382     False              True
# 42387      True             False
# 42390     False              True
# 42403     False              True
# 42418     False             False
# 42427      True             False
# 42439     False              True
#
# [2650 rows x 45 columns]

# %%
import matplotlib.pyplot as plt 
w = [0.2,0.2]
plt.bar([0-0.1,1-0.1], df.target.value_counts(), width=w)
plt.bar([0,1],df[~df.emp_Self & ~df.emp_Army & ~df.emp_KnownCompany].target.value_counts(), width=w)
plt.bar([0+0.1,1+0.1],df[df.emp_Self | df.emp_Army | df.emp_KnownCompany].target.value_counts(), width=w)
plt.xticks([0,1])
#df[~df.emp_Self & ~df.emp_Army & ~df.emp_KnownCompany].target.plot.hist()
# Out:
# ([<matplotlib.axis.XTick at 0x123b4a860>,
#   <matplotlib.axis.XTick at 0x123b4a198>],
#  <a list of 2 Text xticklabel objects>)

# %%
#for e in df[~df.emp_Self & ~df.emp_Army]

df[~df.emp_Self & ~df.emp_Army].emp_title.isin(df_company.Company).value_counts()
# Out:
# False    36168
# True      1988
# Name: emp_title, dtype: int64

# %%
df[~df.emp_Self & ~df.emp_Army][~df[~df.emp_Self & ~df.emp_Army].emp_title.isin(df_company.Company)].emp_title
# Out:
# 1                                          Ryder
# 3                            AIR RESOURCES BOARD
# 5                           Veolia Transportaton
# 6                      Southern Star Photography
# 7                                MKC Accounting
# 10                         Southwest Rural metro
# 11                                          UCLA
# 12           Va. Dept of Conservation/Recreation
# 14                                         SFMTA
# 15                      Internal revenue Service
# 16                             Chin's Restaurant
# 17                                      Duracell
# 18                         Connection Inspection
# 19                  Network Interpreting Service
# 20              Archdiocese of Galveston Houston
# 21                                Osram Sylvania
# 22                                     Value Air
# 23                              Wells Fargo Bank
# 24                               bmg-educational
# 25                Winfield Pathology Consultants
# 26                                   nyc transit
# 27                                     Frito Lay
# 28       Shands Hospital at the University of Fl
# 29                                Oakridge homes
# 31            Audubon Mutual Housing Corporation
# 33                        Good Samaritan Society
# 34                          GREG BARRETT DRYWALL
# 35                               Sharp Lawn Inc.
# 36                         Department of Justice
# 37                               Gateway Hospice
#                           ...
# 42417                        Sikeston R6 Schools
# 42419                                   local 16
# 42420                         Miami Dade College
# 42421                      enterprise rent a car
# 42422                      College of the Ozarks
# 42423                        Lead Media Partners
# 42424          International finance Corporation
# 42425                                Wilson Tire
# 42426                        Mustang Enterprises
# 42428                            Rouge Moira LLC
# 42429                               Williams Lea
# 42430                                  Homedepot
# 42431                   Dr. Cathy Andricsak, DDS
# 42432                          Peter J Oliff DDS
# 42434                             PGIII Services
# 42435                                    retired
# 42436                          Purdue University
# 42437                  Winkel Construction, Inc.
# 42438                          disabled, student
# 42440             Georgia Institue of Technology
# 42441                       swift transportation
# 42442                          Thomson Financial
# 42443                        national employment
# 42444                                      Sears
# 42446                       neurology associates
# 42448                    Brookdale Senior Living
# 42449                Crawford Tracey Corporation
# 42454                          PEER Center, Inc.
# 42466                Securitas Security Services
# 42474                           LendingTree, LLC
# Name: emp_title, Length: 36168, dtype: object

# %%
# Bank
df['emp_Bank'] = df.emp_title.apply(lambda x: (re.search('bank',x ,re.I) is None) == False)

# %%
df[df['emp_Bank']].shape
# Out:
# (933, 46)

# %%
# Public employe
df['emp_Public'] = df.emp_title.apply(lambda x: (re.search('city|state|public|district|school|schools|Government|Sheriff|county|civil|police|National Guard',x ,re.I) is None) == False)

# %%
# Courts

# %%
#federal

# %%
x = 'Cit of stat'
(re.search('city|state',x ,re.I) is None) == False
# Out:
# False

# %%
df[df['emp_Public']].shape
# Out:
# (3789, 47)

# %%
df[df.emp_title == 'Toyotaa'].emp_KnownCompany
# Out:
# Series([], Name: emp_KnownCompany, dtype: bool)

# %%
df_company.Company.str.contains('Toyotaa').value_counts()
# Out:
# False    1984
# Name: Company, dtype: int64

# %%
s = 0
for e in df.emp_title:
    try:
        founds = df_company.Company.str.contains(e).value_counts()
    except:
        print(e)
        
    if len(founds)>1:
        s +=1
# Out:
# /Users/arnescheunemann/opt/anaconda3/envs/nf2/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   after removing the cwd from sys.path.
# New Jersey Institute Of Technology (NJIT
# FCCI Insurance Grou[
# The Keith Corp. (empl by county, now Kei
# Barclays Capital (formerly Lehman Brothe
# Dept of VA (NCCPAC
# 1)-Yavapai Regional Medical Center 2)- Dr. cantors office

# %%
s
# Out:
# 2464
